# %%
import pandas
from matplotlib import pyplot as plt
import numpy
import seaborn
import sklearn

# %%
data = pandas.read_csv("Download Data - STOCK_US_XNAS_AAPL.csv")
data1 = pandas.read_csv("Download Data - INDEX_US_S&P US_SPX.csv")

# %%
plt.title("Apple Share Price")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.plot(data["Date"], data["High"], label="High")
plt.plot(data["Date"], data["Low"], label="Low")
